# %%
import pandas as pd
from sodapy import Socrata
from datetime import datetime

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ### Scraping Chicago Crime Data for last 10 years (2014-2023)

# %%
api_token = "DQdKNTCLRmXZ2yDZBqPY8HBpM"

client = Socrata("data.cityofchicago.org", api_token)

start_date = "2014-01-01T00:00:00.000"
end_date = "2014-12-31T23:59:59.999"

dataset_identifier = "qnmj-8ku6"

query = f"date between '{start_date}' and '{end_date}'"

results = client.get(dataset_identifier, where=query, limit=500000)

client.close()

df_2014 = pd.DataFrame.from_records(results)

print(df_2014.head())
# Out:
#                       date  \
# 0  2014-12-31T23:58:00.000
# 1  2014-12-31T23:50:00.000
# 2  2014-12-31T23:50:00.000
# 3  2014-12-31T23:50:00.000
# 4  2014-12-31T23:46:00.000
#
#                                                                                                                                                       location  \
# 0   {'latitude': '41.99355926', 'human_address': '{"address": "", "city": "", "state": "", "zip": ""}', 'needs_recoding': False, 'longitude': '-87.683592691'}
# 1   {'latitude': '41.750468387', 'human_address': '{"address": "", "city": "", "state": "", "zip": ""}', 'needs_recoding': False, 'longitude': '-87.65561467'}
# 2   {'latitude': '41.824851907', 'human_address': '{"address": "", "city": "", "state": "", "zip": ""}', 'needs_recoding': False, 'longitude': '-87.61140535'}
# 3  {'latitude': '41.892407716', 'human_address': '{"address": "", "city": "", "state": "", "zip": ""}', 'needs_recoding': False, 'longitude': '-87.721100762'}
# ...

# %%
df_2018.shape
# Out:
# (268943, 22)

# %%
start_date = "2015-01-01T00:00:00.000"
end_date = "2015-12-31T23:59:59.999"

dataset_identifier = "vwwp-7yr9"

query = f"date between '{start_date}' and '{end_date}'"

results = client.get(dataset_identifier, where=query, limit=500000)

client.close()

df_2015 = pd.DataFrame.from_records(results)

print(df_2015.head())
# Out:
#                       date district                     block  \
# 0  2015-12-31T23:59:00.000      014        015XX N KEDZIE AVE
# 1  2015-12-31T23:59:00.000      006       075XX S EMERALD AVE
# 2  2015-12-31T23:55:00.000      004  079XX S STONY ISLAND AVE
# 3  2015-12-31T23:50:00.000      024         024XX W FARGO AVE
# 4  2015-12-31T23:50:00.000      019          037XX N CLARK ST
#
#                      description     location_description  \
# 0                  FROM BUILDING  RESIDENCE PORCH/HALLWAY
# 1                     TO VEHICLE                   STREET
# 2  AGGRAVATED: OTHER DANG WEAPON                   STREET
# 3                 $500 AND UNDER                APARTMENT
# 4                         SIMPLE                 SIDEWALK
#
#                 updated_on community_area  iucr ward case_number  year  \
# 0  2018-02-09T15:44:29.000             23  0890   26    HZ199559  2015
# 1  2018-02-10T15:50:01.000             68  1320   17    HZ100370  2015
# ...

# %%
start_date = "2016-01-01T00:00:00.000"
end_date = "2016-12-31T23:59:59.999"

dataset_identifier = "kf95-mnd6"

query = f"date between '{start_date}' and '{end_date}'"

results = client.get(dataset_identifier, where=query, limit=500000)

client.close()

df_2016 = pd.DataFrame.from_records(results)

print(df_2016.head())
# Out:
#                       date  \
# 0  2016-12-31T23:59:00.000
# 1  2016-12-31T23:58:00.000
# 2  2016-12-31T23:55:00.000
# 3  2016-12-31T23:55:00.000
# 4  2016-12-31T23:54:00.000
#
#                                                                                                                                                       location  \
# 0  {'latitude': '41.976290414', 'human_address': '{"address": "", "city": "", "state": "", "zip": ""}', 'needs_recoding': False, 'longitude': '-87.905227221'}
# 1  {'latitude': '41.688033246', 'human_address': '{"address": "", "city": "", "state": "", "zip": ""}', 'needs_recoding': False, 'longitude': '-87.623931468'}
# 2   {'latitude': '41.936884881', 'human_address': '{"address": "", "city": "", "state": "", "zip": ""}', 'needs_recoding': False, 'longitude': '-87.66476981'}
# 3  {'latitude': '41.886814897', 'human_address': '{"address": "", "city": "", "state": "", "zip": ""}', 'needs_recoding': False, 'longitude': '-87.625592678'}
# ...

# %%
start_date = "2017-01-01T00:00:00.000"
end_date = "2017-12-31T23:59:59.999"

dataset_identifier = "d62x-nvdr"

query = f"date between '{start_date}' and '{end_date}'"

results = client.get(dataset_identifier, where=query, limit=500000)

client.close()

df_2017 = pd.DataFrame.from_records(results)

print(df_2017.head())
# Out:
#                       date  \
# 0  2017-12-31T23:58:00.000
# 1  2017-12-31T23:50:00.000
# 2  2017-12-31T23:48:00.000
# 3  2017-12-31T23:45:00.000
# 4  2017-12-31T23:45:00.000
#
#                                                                                                                                                       location  \
# 0  {'latitude': '41.965693651', 'human_address': '{"address": "", "city": "", "state": "", "zip": ""}', 'needs_recoding': False, 'longitude': '-87.715726125'}
# 1  {'latitude': '41.926558908', 'human_address': '{"address": "", "city": "", "state": "", "zip": ""}', 'needs_recoding': False, 'longitude': '-87.631294073'}
# 2  {'latitude': '41.895750913', 'human_address': '{"address": "", "city": "", "state": "", "zip": ""}', 'needs_recoding': False, 'longitude': '-87.623495923'}
# 3  {'latitude': '41.683369303', 'human_address': '{"address": "", "city": "", "state": "", "zip": ""}', 'needs_recoding': False, 'longitude': '-87.622829524'}
# ...

# %%
start_date = "2018-01-01T00:00:00.000"
end_date = "2018-12-31T23:59:59.999"

dataset_identifier = "3i3m-jwuy"

query = f"date between '{start_date}' and '{end_date}'"

results = client.get(dataset_identifier, where=query, limit=500000)

client.close()

df_2018 = pd.DataFrame.from_records(results)

print(df_2018.head())
# Out:
#                       date  \
# 0  2018-12-31T23:59:00.000
# 1  2018-12-31T23:59:00.000
# 2  2018-12-31T23:59:00.000
# 3  2018-12-31T23:57:00.000
# 4  2018-12-31T23:56:00.000
#
#                                                                                                                                                       location  \
# 0  {'latitude': '41.763181359', 'human_address': '{"address": "", "city": "", "state": "", "zip": ""}', 'needs_recoding': False, 'longitude': '-87.657709477'}
# 1  {'latitude': '41.689078832', 'human_address': '{"address": "", "city": "", "state": "", "zip": ""}', 'needs_recoding': False, 'longitude': '-87.696064026'}
# 2                                                                                                                                                          NaN
# 3  {'latitude': '41.740520866', 'human_address': '{"address": "", "city": "", "state": "", "zip": ""}', 'needs_recoding': False, 'longitude': '-87.647390719'}
# ...

# %%
start_date = "2019-01-01T00:00:00.000"
end_date = "2019-12-31T23:59:59.999"

dataset_identifier = "w98m-zvie"

query = f"date between '{start_date}' and '{end_date}'"

results = client.get(dataset_identifier, where=query, limit=500000)

client.close()

df_2019 = pd.DataFrame.from_records(results)

print(df_2019.head())
# Out:
#                       date  \
# 0  2019-12-31T23:55:00.000
# 1  2019-12-31T23:54:00.000
# 2  2019-12-31T23:50:00.000
# 3  2019-12-31T23:48:00.000
# 4  2019-12-31T23:46:00.000
#
#                                                                                                                                                       location  \
# 0  {'latitude': '41.769150218', 'human_address': '{"address": "", "city": "", "state": "", "zip": ""}', 'needs_recoding': False, 'longitude': '-87.627136786'}
# 1  {'latitude': '41.779173667', 'human_address': '{"address": "", "city": "", "state": "", "zip": ""}', 'needs_recoding': False, 'longitude': '-87.653277703'}
# 2                                                                                                                                                          NaN
# 3  {'latitude': '41.874623951', 'human_address': '{"address": "", "city": "", "state": "", "zip": ""}', 'needs_recoding': False, 'longitude': '-87.745052647'}
# ...

# %%
start_date = "2020-01-01T00:00:00.000"
end_date = "2020-12-31T23:59:59.999"

dataset_identifier = "qzdf-xmn8"

query = f"date between '{start_date}' and '{end_date}'"

results = client.get(dataset_identifier, where=query, limit=500000)

client.close()

df_2020 = pd.DataFrame.from_records(results)

print(df_2020.head())
# Out:
#                       date  \
# 0  2020-12-31T23:59:00.000
# 1  2020-12-31T23:51:00.000
# 2  2020-12-31T23:45:00.000
# 3  2020-12-31T23:45:00.000
# 4  2020-12-31T23:45:00.000
#
#                                                                                                                                                       location  \
# 0    {'latitude': '41.9116839', 'human_address': '{"address": "", "city": "", "state": "", "zip": ""}', 'needs_recoding': False, 'longitude': '-87.745917518'}
# 1  {'latitude': '41.863406877', 'human_address': '{"address": "", "city": "", "state": "", "zip": ""}', 'needs_recoding': False, 'longitude': '-87.710455868'}
# 2                                                                                                                                                          NaN
# 3  {'latitude': '41.792043078', 'human_address': '{"address": "", "city": "", "state": "", "zip": ""}', 'needs_recoding': False, 'longitude': '-87.624017919'}
# ...

# %%
start_date = "2021-01-01T00:00:00.000"
end_date = "2021-12-31T23:59:59.999"

dataset_identifier = "dwme-t96c"

query = f"date between '{start_date}' and '{end_date}'"

results = client.get(dataset_identifier, where=query, limit=500000)

client.close()

df_2021 = pd.DataFrame.from_records(results)

print(df_2021.head())
# Out:
#                       date  \
# 0  2021-12-31T23:59:00.000
# 1  2021-12-31T23:59:00.000
# 2  2021-12-31T23:58:00.000
# 3  2021-12-31T23:55:00.000
# 4  2021-12-31T23:50:00.000
#
#                                                                                                                                                       location  \
# 0   {'latitude': '41.894327846', 'human_address': '{"address": "", "city": "", "state": "", "zip": ""}', 'needs_recoding': False, 'longitude': '-87.62814321'}
# 1                                                                                                                                                          NaN
# 2  {'latitude': '41.745680051', 'human_address': '{"address": "", "city": "", "state": "", "zip": ""}', 'needs_recoding': False, 'longitude': '-87.558851198'}
# 3   {'latitude': '41.734916889', 'human_address': '{"address": "", "city": "", "state": "", "zip": ""}', 'needs_recoding': False, 'longitude': '-87.66790905'}
# ...

# %%
start_date = "2022-01-01T00:00:00.000"
end_date = "2022-12-31T23:59:59.999"

dataset_identifier = "9hwr-2zxp"

query = f"date between '{start_date}' and '{end_date}'"

results = client.get(dataset_identifier, where=query, limit=500000)

client.close()

df_2022 = pd.DataFrame.from_records(results)

print(df_2022.head())
# Out:
#                       date district                    block  \
# 0  2022-12-31T23:59:00.000      010        037XX W OGDEN AVE
# 1  2022-12-31T23:55:00.000      015         055XX W ADAMS ST
# 2  2022-12-31T23:50:00.000      024         014XX W LUNT AVE
# 3  2022-12-31T23:50:00.000      015  055XX W WASHINGTON BLVD
# 4  2022-12-31T23:47:00.000      022        091XX S LAFLIN ST
#
#                      description             location_description  \
# 0                 NON-AGGRAVATED          MEDICAL / DENTAL OFFICE
# 1     RECKLESS FIREARM DISCHARGE  RESIDENCE - YARD (FRONT / BACK)
# 2                     AUTOMOBILE                            ALLEY
# 3        DOMESTIC BATTERY SIMPLE                        APARTMENT
# 4  UNLAWFUL POSSESSION - HANDGUN                        APARTMENT
#
#                 updated_on community_area  iucr ward case_number  year  \
# 0  2024-01-06T15:41:12.000             29  0281   24    JH105773  2022
# ...

# %%
start_date = "2023-01-01T00:00:00.000"

end_date = datetime.now().strftime("%Y-%m-%dT%H:%M:%S.000")

dataset_identifier = "xguy-4ndq"

query = f"date between '{start_date}' and '{end_date}'"

results = client.get(dataset_identifier, where=query, limit=1000000)

client.close()

df_2023= pd.DataFrame.from_records(results)

print(df_2023.head())
# Out:
#                       date  \
# 0  2023-12-31T23:59:00.000
# 1  2023-12-31T23:51:00.000
# 2  2023-12-31T23:51:00.000
# 3  2023-12-31T23:50:00.000
# 4  2023-12-31T23:50:00.000
#
#                                                                                                                                                       location  \
# 0  {'latitude': '41.900698378', 'human_address': '{"address": "", "city": "", "state": "", "zip": ""}', 'needs_recoding': False, 'longitude': '-87.637329754'}
# 1  {'latitude': '41.754966726', 'human_address': '{"address": "", "city": "", "state": "", "zip": ""}', 'needs_recoding': False, 'longitude': '-87.602410989'}
# 2  {'latitude': '41.801583507', 'human_address': '{"address": "", "city": "", "state": "", "zip": ""}', 'needs_recoding': False, 'longitude': '-87.633177068'}
# 3  {'latitude': '41.800200965', 'human_address': '{"address": "", "city": "", "state": "", "zip": ""}', 'needs_recoding': False, 'longitude': '-87.691535096'}
# ...

# %%
df_2014.columns
# Out:
# Index(['date', 'location', 'district', 'block', 'y_coordinate', 'latitude',
#        'description', 'location_description', 'updated_on', 'community_area',
#        'iucr', 'x_coordinate', 'ward', 'case_number', 'year', 'domestic',
#        'fbi_code', 'longitude', 'beat', 'primary_type', 'arrest', 'id'],
#       dtype='object')

# %%
def find_min_max_dates(dataframes):
    """
    Takes a list of pandas DataFrames, each with a 'date' column, and prints the min and max date for each.
    
    :param dataframes: List of pandas DataFrames
    """
    for df in dataframes:
        if 'date' in df.columns:
            df['date'] = pd.to_datetime(df['date'])
            min_date = df['date'].min()
            max_date = df['date'].max()
            print(f"Minimum Date: {min_date}, Maximum Date: {max_date}")
        else:
            print("DataFrame does not have a 'date' column")

# %%
dataframes_list = [df_2023, df_2022, df_2021, df_2020, df_2019, df_2018, df_2017, df_2016, df_2015, df_2014]

find_min_max_dates(dataframes_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/rashidbaset/Documents/my-projects/crime-home-price-prediction-capstone/chicago-crime-property-analysis/data-clean.ipynb Cell 16 line 3
#       <a href='vscode-notebook-cell:/Users/rashidbaset/Documents/my-projects/crime-home-price-prediction-capstone/chicago-crime-property-analysis/data-clean.ipynb#X21sZmlsZQ%3D%3D?line=0'>1</a> dataframes_list = [df_2023, df_2022, df_2021, df_2020, df_2019, df_2018, df_2017, df_2016, df_2015, df_2014]
# ----> <a href='vscode-notebook-cell:/Users/rashidbaset/Documents/my-projects/crime-home-price-prediction-capstone/chicago-crime-property-analysis/data-clean.ipynb#X21sZmlsZQ%3D%3D?line=2'>3</a> find_min_max_dates(dataframes_list)
#
# NameError: name 'find_min_max_dates' is not defined

# %%
# Concatenate all DataFrames into one
crime_df = pd.concat(dataframes_list, ignore_index=True)

crime_df.head()
# Out:
#                       date  \
# 0  2023-12-31T23:59:00.000
# 1  2023-12-31T23:51:00.000
# 2  2023-12-31T23:51:00.000
# 3  2023-12-31T23:50:00.000
# 4  2023-12-31T23:50:00.000
#
#                                                                                                                                                       location  \
# 0  {'latitude': '41.900698378', 'human_address': '{"address": "", "city": "", "state": "", "zip": ""}', 'needs_recoding': False, 'longitude': '-87.637329754'}
# 1  {'latitude': '41.754966726', 'human_address': '{"address": "", "city": "", "state": "", "zip": ""}', 'needs_recoding': False, 'longitude': '-87.602410989'}
# 2  {'latitude': '41.801583507', 'human_address': '{"address": "", "city": "", "state": "", "zip": ""}', 'needs_recoding': False, 'longitude': '-87.633177068'}
# 3  {'latitude': '41.800200965', 'human_address': '{"address": "", "city": "", "state": "", "zip": ""}', 'needs_recoding': False, 'longitude': '-87.691535096'}
# ...

# %%
crime_df.shape
# Out:
# (2530454, 22)

# %%
csv_file_path = "crime_2014_2023.csv"

# Export the DataFrame to a CSV file
crime_df.to_csv(csv_file_path, index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/rashidbaset/Documents/my-projects/crime-home-price-prediction-capstone/chicago-crime-property-analysis/data-clean.ipynb Cell 20 line 4
#       <a href='vscode-notebook-cell:/Users/rashidbaset/Documents/my-projects/crime-home-price-prediction-capstone/chicago-crime-property-analysis/data-clean.ipynb#X25sZmlsZQ%3D%3D?line=0'>1</a> csv_file_path = "crime_2014_2023.csv"
#       <a href='vscode-notebook-cell:/Users/rashidbaset/Documents/my-projects/crime-home-price-prediction-capstone/chicago-crime-property-analysis/data-clean.ipynb#X25sZmlsZQ%3D%3D?line=2'>3</a> # Export the DataFrame to a CSV file
# ...

# %%
crime_df = pd.read_csv("/Users/rashidbaset/Documents/my-projects/crime-home-price-prediction-capstone/chicago-crime-property-analysis/crime_2014_2023.csv")

# %%
crime_df.shape
# Out:
# (2530216, 22)

# %%
import geopandas as gpd
from shapely.geometry import Point

crime_geometry = [Point(xy) for xy in zip(crime_df['longitude'], crime_df['latitude'])]

crime_df = gpd.GeoDataFrame(crime_df, geometry=crime_geometry, crs='EPSG:4326')

neighborhoods = gpd.read_file('/Users/rashidbaset/Documents/my-projects/crime-home-price-prediction-capstone/chicago-crime-property-analysis/boundries-chicago.geojson')

crime_df = gpd.sjoin(crime_df, neighborhoods, op='within')
# Out:
# /Users/rashidbaset/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3466: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):

# %%
neighborhood_categories = {
    "South Side": [
        "SOUTH SHORE", "AUBURN GRESHAM", "ROSELAND", "CHATHAM", "GREATER GRAND CROSSING",
        "SOUTH CHICAGO", "CHICAGO LAWN", "ENGLEWOOD", "WEST PULLMAN", "GARFIELD RIDGE",
        "ASHBURN", "AVALON PARK", "MORGAN PARK", "GRAND BOULEVARD", "WOODLAWN", "SOUTH LAWNDALE",
        "KENWOOD", "CALUMET HEIGHTS", "DOUGLAS", "GAGE PARK", "WEST ELSDON", "SOUTH DEERING",
        "HEGEWISCH", "AVALON PARK", "WASHINGTON PARK", "ARMOUR SQUARE", "PULLMAN", "OAKLAND",
        "FULLER PARK", "BURNSIDE", "RIVERDALE"
    ],
    "Southwest Side": [
        "CLEARING", "WEST LAWN", "WEST ELSDON", "GARFIELD RIDGE",
        "ARCHER HEIGHTS", "BRIGHTON PARK", "MCKINLEY PARK"
    ],
    "Far Southwest Side": [
        "MOUNT GREENWOOD", "BEVERLY", "WASHINGTON HEIGHTS"
    ],
    "Southeast Side": [
        "HEGEWISCH", "SOUTH DEERING"
    ],
    "Central": [
        "NEAR NORTH SIDE", "LAKE VIEW", "WEST TOWN", "LINCOLN PARK", "NEAR WEST SIDE", "LOOP", "LOGAN SQUARE",
        "EDGEWATER", "UPTOWN"
    ],
    "Far North Side": [
        "ROGERS PARK", "NORWOOD PARK", "DUNNING", "EDISON PARK", "NORTH PARK"
    ],
    "North Side": [
        "NORTH CENTER", "LAKE VIEW", "LINCOLN PARK", "EDGEWATER", "UPTOWN"
    ],
    "Northwest Side": [
        "PORTAGE PARK", "WEST RIDGE", "IRVING PARK", "ALBANY PARK", "JEFFERSON PARK", "MONTCLARE", "HERMOSA"
    ],
    "West Side": [
        "AUSTIN", "WEST ENGLEWOOD", "BELMONT CRAGIN", "HUMBOLDT PARK", "AVONDALE", "NEW CITY", "CLEARING",
        "NORTH LAWNDALE", "BRIDGEPORT", "MOUNT GREENWOOD", "FOREST GLEN", "SOUTH LAWNDALE", "KENWOOD",
        "OHARE", "LOWER WEST SIDE", "EAST GARFIELD PARK", "EAST SIDE", "WEST GARFIELD PARK", "CALUMET HEIGHTS",
        "DOUGLAS", "WEST ELSDON", "HEGEWISCH", "AVALON PARK", "MCKINLEY PARK", "HERMOSA", "WASHINGTON PARK",
        "ARMOUR SQUARE", "ARCHER HEIGHTS", "PULLMAN", "OAKLAND", "FULLER PARK", "BURNSIDE", "RIVERDALE"
    ]
}

crime_df['Neighborhood'] = crime_df['community'].apply(lambda x: next((k for k, v in neighborhood_categories.items() if x in v), 'Other'))

# %%
crime_df['date'] = pd.to_datetime(crime_df['date'])

# %%
crime_df = crime_df.drop('location', axis=1)

# %%
missing_values = crime_df.isnull().sum()

total_rows = len(crime_df)

percentage_missing = (missing_values / total_rows) * 100

missing_data_summary = pd.DataFrame({
    'Column Name': missing_values.index,
    'Missing Values': missing_values.values,
    'Percentage Missing': percentage_missing.values
})

print(missing_data_summary)
# Out:
#              Column Name  Missing Values  Percentage Missing
# 0                   date               0            0.000000
# 1               district               0            0.000000
# 2                  block               0            0.000000
# 3            description               0            0.000000
# 4   location_description            2079            0.416754
# 5             updated_on               0            0.000000
# 6         community_area               0            0.000000
# 7                   iucr               0            0.000000
# 8                   ward              13            0.002606
# 9            case_number               0            0.000000
# 10                  year               0            0.000000
# 11              domestic               0            0.000000
# 12              fbi_code               0            0.000000
# 13                  beat               0            0.000000
# ...

# %% [markdown]
# ### Scraping Property Data From Realtor.com

# %%
from homeharvest import scrape_property
from datetime import datetime, timedelta
import pandas as pd
import time
from requests.exceptions import HTTPError

dataframes_list = []
start_date = datetime.now() - timedelta(days=365 * 10)  # 10 years ago
end_date = datetime.now()
date_range = (end_date - start_date).days
segments = 120  
days_per_request = date_range // segments
max_retries = 5
retry_delay = 10  # seconds

for i in range(segments):
    date_from = start_date + timedelta(days=i * days_per_request)
    date_to = date_from + timedelta(days=days_per_request - 1)

    for attempt in range(max_retries):
        try:
            fetched_df = scrape_property(
                location="Chicago, IL",
                listing_type="sold",
                date_from=date_from.strftime("%Y-%m-%d"),
                date_to=date_to.strftime("%Y-%m-%d")
            )
            print(f"Segment {i+1}, Dates: {date_from.strftime('%Y-%m-%d')} to {date_to.strftime('%Y-%m-%d')}, Number of properties: {len(fetched_df)}")
            dataframes_list.append(fetched_df)
            break  # If the request is successful, break out of the retry loop
        except HTTPError as e:
            print(f"HTTP error on attempt {attempt + 1} of {max_retries}: {e}")
            if attempt < max_retries - 1:
                time.sleep(retry_delay)  # Wait before retrying
            else:
                raise  # Re-raise the last exception if all retries fail

combined_df = pd.concat(dataframes_list, ignore_index=True)

print(f"Total Number of properties: {len(combined_df)}")

filename = "HomeHarvest_Chicago_10Years_2.csv"
combined_df.to_csv(filename, index=False)
# Out:
# Segment 1, Dates: 2014-01-13 to 2014-02-11, Number of properties: 1583
# Segment 2, Dates: 2014-02-12 to 2014-03-13, Number of properties: 1509
# Segment 3, Dates: 2014-03-14 to 2014-04-12, Number of properties: 2148
# Segment 4, Dates: 2014-04-13 to 2014-05-12, Number of properties: 1871
# Segment 5, Dates: 2014-05-13 to 2014-06-11, Number of properties: 1992
# Segment 6, Dates: 2014-06-12 to 2014-07-11, Number of properties: 1750
# Segment 7, Dates: 2014-07-12 to 2014-08-10, Number of properties: 1499
# Segment 8, Dates: 2014-08-11 to 2014-09-09, Number of properties: 1860
# Segment 9, Dates: 2014-09-10 to 2014-10-09, Number of properties: 2552
# Segment 10, Dates: 2014-10-10 to 2014-11-08, Number of properties: 1765
# Segment 11, Dates: 2014-11-09 to 2014-12-08, Number of properties: 1607
# Segment 12, Dates: 2014-12-09 to 2015-01-07, Number of properties: 1637
# Segment 13, Dates: 2015-01-08 to 2015-02-06, Number of properties: 1381
# ...

# %%
property_df = pd.read_csv("HomeHarvest_Chicago_10years.csv")
# Out:
# /var/folders/pp/77rpffxd5pl6p9fys4m6t7y00000gn/T/ipykernel_18745/3074681795.py:1: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   property_df = pd.read_csv("HomeHarvest_Chicago_10years.csv")

# %%
#columns_to_remove = ['primary_photo', 'alt_photos', 'mls', 'status', 'unit', 'city', 'state']

#property_df = property_df.drop(columns=columns_to_remove)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/rashidbaset/Documents/my-projects/crime-home-price-prediction-capstone/chicago-crime-property-analysis/data-clean.ipynb Cell 25 line 3
#       <a href='vscode-notebook-cell:/Users/rashidbaset/Documents/my-projects/crime-home-price-prediction-capstone/chicago-crime-property-analysis/data-clean.ipynb#X34sZmlsZQ%3D%3D?line=0'>1</a> columns_to_remove = ['primary_photo', 'alt_photos', 'mls', 'status', 'unit', 'city', 'state']
# ----> <a href='vscode-notebook-cell:/Users/rashidbaset/Documents/my-projects/crime-home-price-prediction-capstone/chicago-crime-property-analysis/data-clean.ipynb#X34sZmlsZQ%3D%3D?line=2'>3</a> property_df = property_df.drop(columns=columns_to_remove)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %% [markdown]
# #### List date

# %%
property_df['list_date'] = pd.to_datetime(property_df['list_date'], errors='coerce')
property_df['list_year'] = property_df['list_date'].dt.year
missing_data_by_year = property_df.groupby('list_year')['list_date'].apply(lambda x: x.isnull().mean()).reset_index()
missing_data_by_year.columns = ['list_year', 'percentage_missing']
print(missing_data_by_year)

# %%
# Check the 'list_year' values for rows with missing 'list_date'
missing_list_date_rows = property_df[property_df['list_date'].isnull()]
print(missing_list_date_rows['list_year'].unique())

# %%
property_df['list_date'] = pd.to_datetime(property_df['list_date'], errors='coerce')
property_df['list_year'] = property_df['list_date'].dt.year

# Filter out rows with missing 'list_date' values
property_df_filtered = property_df[~property_df['list_date'].isnull()]

missing_data_by_year = property_df_filtered.groupby('list_year')['list_date'].apply(lambda x: x.isnull().mean())
missing_data_by_year = missing_data_by_year.reset_index()
missing_data_by_year.columns = ['list_year', 'percentage_missing']
print(missing_data_by_year)

# %%
property_df['list_date'] = pd.to_datetime(property_df['list_date'], errors='coerce')
property_df['list_year'] = property_df['list_date'].dt.year

# Group by 'list_year' and calculate the percentage of NaN values in 'list_date' for each year
missing_data_by_year = property_df.groupby('list_year')['list_date'].apply(lambda x: x.isnull().mean() * 100)
missing_data_by_year = missing_data_by_year.reset_index()
missing_data_by_year.columns = ['list_year', 'percentage_missing']
print(missing_data_by_year)

# %%
import pandas as pd

# Assuming property_df is your DataFrame
property_df['list_date'] = pd.to_datetime(property_df['list_date'], errors='coerce')

# Set display option to show all rows
pd.set_option('display.max_rows', None)

# Calculate the percentage of missing values for each community in 'list_date'
percent_missing_by_community = property_df.groupby('community')['list_date'].apply(lambda x: x.isna().sum() * 100 / len(x)).reset_index()
percent_missing_by_community.columns = ['community', 'percent_missing']

# Sort the DataFrame by 'percent_missing'
percent_missing_by_community.sort_values('percent_missing', inplace=True)

# Reset display option to default
pd.reset_option('display.max_rows')

print(percent_missing_by_community)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming property_df is your DataFrame
property_df['list_date'] = pd.to_datetime(property_df['list_date'], errors='coerce')
property_df['last_sold_date'] = pd.to_datetime(property_df['last_sold_date'], errors='coerce')

# Calculate the percentage of missing 'list_date' values based on the year from 'last_sold_date'
property_df['list_year'] = property_df.apply(lambda row: row['last_sold_date'].year if pd.notna(row['last_sold_date']) else None, axis=1)
percent_missing_by_year = property_df.groupby('list_year')['list_date'].apply(lambda x: x.isna().sum() * 100 / len(x)).reset_index()
percent_missing_by_year.columns = ['list_year', 'percent_missing']

# Sort the DataFrame by 'list_year'
percent_missing_by_year.sort_values('list_year', inplace=True)

# Create a bar graph
plt.figure(figsize=(10, 6))
plt.bar(percent_missing_by_year['list_year'], percent_missing_by_year['percent_missing'])
plt.xlabel('Year')
plt.ylabel('Percentage Missing')
plt.title('Percentage of Missing list_date Values by Year')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming property_df is your DataFrame
property_df['list_date'] = pd.to_datetime(property_df['list_date'], errors='coerce')

# Calculate the percentage of missing values for each 'style' category in 'list_date'
percent_missing_by_style = property_df.groupby('style')['list_date'].apply(lambda x: x.isna().sum() * 100 / len(x)).reset_index()
percent_missing_by_style.columns = ['style', 'percent_missing']

# Sort the DataFrame by 'percent_missing'
percent_missing_by_style.sort_values('percent_missing', inplace=True)

# Create a bar graph
plt.figure(figsize=(12, 6))
sns.barplot(x='percent_missing', y='style', data=percent_missing_by_style)
plt.xlabel('Percentage Missing')
plt.ylabel('Style')
plt.title('Percentage of Missing list_date Values by Style')
plt.tight_layout()
plt.show()

# %%
import pandas as pd

# Assuming property_df is your DataFrame
property_df['list_date'] = pd.to_datetime(property_df['list_date'], errors='coerce')

# Filter the DataFrame for the specified styles
selected_styles = ['condos', 'CONDO_TOWNHOME_ROWHOME_COOP', 'FARM', 'MOBILE']
filtered_df = property_df[property_df['style'].isin(selected_styles)]

# Calculate the percentage of missing 'list_date' values for each selected style
percent_missing_by_style = filtered_df.groupby('style')['list_date'].apply(lambda x: x.isna().sum() * 100 / len(x)).reset_index()
percent_missing_by_style.columns = ['style', 'percent_missing']

# Print the result
print(percent_missing_by_style)

# %%
import pandas as pd

# Assuming property_df is your DataFrame
selected_styles = ['CONDOS', 'CONDO_TOWNHOME_ROWHOME_COOP', 'FARM', 'MOBILE']

# Calculate the percentage for each selected style
style_percentages = {}
for style in selected_styles:
    percentage = (property_df['style'] == style).sum() * 100 / len(property_df)
    style_percentages[style] = percentage

# Print the percentages for each style
for style, percentage in style_percentages.items():
    print(f"Percentage of 'style' values that are '{style}': {percentage:.2f}%")

# %%
import pandas as pd

# Assuming property_df is your DataFrame
property_df['lot_sqft_missing'] = property_df['lot_sqft'].isnull()
property_df['sold_price_category'] = pd.cut(property_df['sold_price'], bins=[0, 500000, 1000000, 1500000, float('inf')], labels=['<500K', '500K-1M', '1M-1.5M', '1.5M+'])

# Calculate the percentage of missing 'lot_sqft' values for each sold_price category
percentage_missing_by_price = property_df.groupby('sold_price_category')['lot_sqft_missing'].mean() * 100

print(percentage_missing_by_price)

# %%
import pandas as pd

# Assuming property_df is your DataFrame
property_df['lot_sqft_missing'] = property_df['lot_sqft'].isnull()
property_df['sqft_missing'] = property_df['sqft'].isnull()

# Calculate the percentage of rows with missing 'lot_sqft' that also have missing 'sqft'
percentage_lot_sqft_missing_with_sqft = (property_df['lot_sqft_missing'] & property_df['sqft_missing']).mean() * 100

# Calculate the percentage of rows with missing 'sqft' that also have missing 'lot_sqft'
percentage_sqft_missing_with_lot_sqft = (property_df['sqft_missing'] & property_df['lot_sqft_missing']).mean() * 100

print(f"Percentage of rows missing 'lot_sqft' with missing 'sqft': {percentage_lot_sqft_missing_with_sqft:.2f}%")
print(f"Percentage of rows missing 'sqft' with missing 'lot_sqft': {percentage_sqft_missing_with_lot_sqft:.2f}%")

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming property_df is your DataFrame
property_df['lot_sqft'] = pd.to_numeric(property_df['lot_sqft'], errors='coerce')
property_df['sqft'] = pd.to_numeric(property_df['sqft'], errors='coerce')

property_df['list_year'] = property_df.apply(lambda row: row['last_sold_date'].year if pd.notna(row['last_sold_date']) else None, axis=1)
percent_missing_lot_sqft_by_year = property_df.groupby('list_year')['lot_sqft'].apply(lambda x: x.isna().mean() * 100).reset_index()
percent_missing_sqft_by_year = property_df.groupby('list_year')['sqft'].apply(lambda x: x.isna().mean() * 100).reset_index()

plt.figure(figsize=(10, 6))
plt.bar(percent_missing_lot_sqft_by_year['list_year'], percent_missing_lot_sqft_by_year['lot_sqft'], label='lot_sqft')
plt.bar(percent_missing_sqft_by_year['list_year'], percent_missing_sqft_by_year['sqft'], label='sqft', alpha=0.7)
plt.xlabel('Year')
plt.ylabel('Percentage Missing')
plt.title('Percentage of Missing lot_sqft and sqft Values by Year')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming property_df is your DataFrame
property_df['lot_sqft'] = pd.to_numeric(property_df['lot_sqft'], errors='coerce')
property_df['sqft'] = pd.to_numeric(property_df['sqft'], errors='coerce')

# Calculate the percentage of missing values for each 'style' category in 'lot_sqft'
percent_missing_lot_sqft_by_style = property_df.groupby('style')['lot_sqft'].apply(lambda x: x.isna().mean() * 100).reset_index()
percent_missing_lot_sqft_by_style.columns = ['style', 'percent_missing_lot_sqft']

# Calculate the percentage of missing values for each 'style' category in 'sqft'
percent_missing_sqft_by_style = property_df.groupby('style')['sqft'].apply(lambda x: x.isna().mean() * 100).reset_index()
percent_missing_sqft_by_style.columns = ['style', 'percent_missing_sqft']

# Merge the two DataFrames on 'style'
percent_missing_by_style = pd.merge(percent_missing_lot_sqft_by_style, percent_missing_sqft_by_style, on='style')

# Create a bar graph for 'lot_sqft'
plt.figure(figsize=(12, 6))
sns.barplot(x='percent_missing_lot_sqft', y='style', data=percent_missing_by_style)
plt.xlabel('Percentage Missing lot_sqft')
plt.ylabel('Style')
plt.title('Percentage of Missing lot_sqft Values by Style')
plt.tight_layout()
plt.show()

# Create a bar graph for 'sqft'
plt.figure(figsize=(12, 6))
sns.barplot(x='percent_missing_sqft', y='style', data=percent_missing_by_style)
plt.xlabel('Percentage Missing sqft')
plt.ylabel('Style')
plt.title('Percentage of Missing sqft Values by Style')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming property_df is your DataFrame
property_df['hoa_fee'] = pd.to_numeric(property_df['hoa_fee'], errors='coerce')

# Calculate the percentage of missing values for each 'style' category in 'hoa_fee'
percent_missing_hoa_fee_by_style = property_df.groupby('style')['hoa_fee'].apply(lambda x: x.isna().mean() * 100).reset_index()
percent_missing_hoa_fee_by_style.columns = ['style', 'percent_missing_hoa_fee']

# Sort the DataFrame by 'percent_missing_hoa_fee'
percent_missing_hoa_fee_by_style.sort_values('percent_missing_hoa_fee', inplace=True)

# Create a bar graph
plt.figure(figsize=(12, 6))
sns.barplot(x='percent_missing_hoa_fee', y='style', data=percent_missing_hoa_fee_by_style)
plt.xlabel('Percentage Missing HOA Fee')
plt.ylabel('Style')
plt.title('Percentage of Missing HOA Fee Values by Style')
plt.tight_layout()
plt.show()

# %%
# Assuming property_df is your DataFrame
property_df['list_date_missing'] = property_df['list_date'].isnull()
property_df['list_price_missing'] = property_df['list_price'].isnull()

# Calculate the percentage of rows with missing 'list_date' that also have missing 'list_price'
percentage_list_date_missing_with_list_price = (property_df['list_date_missing'] & property_df['list_price_missing']).mean() * 100

# Calculate the percentage of rows with missing 'list_price' that also have missing 'list_date'
percentage_list_price_missing_with_list_date = (property_df['list_price_missing'] & property_df['list_date_missing']).mean() * 100

print(f"Percentage of rows missing 'list_date' with missing 'list_price': {percentage_list_date_missing_with_list_price:.2f}%")
print(f"Percentage of rows missing 'list_price' with missing 'list_date': {percentage_list_price_missing_with_list_date:.2f}%")

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming property_df is your DataFrame
property_df['price_per_sqft'] = pd.to_numeric(property_df['price_per_sqft'], errors='coerce')

# Calculate the percentage of missing values in 'price_per_sqft'
percent_missing_price_per_sqft = (property_df['price_per_sqft'].isnull().mean()) * 100

# Create a bar chart to visualize the percentage of missing values
plt.figure(figsize=(6, 4))
plt.bar(['price_per_sqft'], [percent_missing_price_per_sqft])
plt.xlabel('Column')
plt.ylabel('Percentage Missing')
plt.title('Percentage of Missing price_per_sqft Values')
plt.ylim(0, 100)
plt.tight_layout()
plt.show()

print(f"Percentage of missing 'price_per_sqft' values: {percent_missing_price_per_sqft:.2f}%")

# %%
property_df.head(5)
# Out:
#                                         property_url     mls_id  \
# 0  https://www.realtor.com/realestateandhomes-det...  8326275.0
# 1  https://www.realtor.com/realestateandhomes-det...        NaN
# 2  https://www.realtor.com/realestateandhomes-det...  8401495.0
# 3  https://www.realtor.com/realestateandhomes-det...  8530200.0
# 4  https://www.realtor.com/realestateandhomes-det...  8461738.0
#
#            style              street  zip_code  beds  full_baths  half_baths  \
# 0  SINGLE_FAMILY    8548 S Bishop St   60620.0     3           1          -1
# 1  SINGLE_FAMILY  7716 S Aberdeen St   60620.0     3           1          -1
# 2  SINGLE_FAMILY  7837 S Wolcott Ave   60620.0     3           1           1
# 3   MULTI_FAMILY  7807 S Sangamon St   60620.0     7           2          -1
# 4  SINGLE_FAMILY  7541 S Aberdeen St   60620.0     2           1           1
#
#    sqft  year_built  ...       community  area    shape_area  perimeter  \
# ...

# %%
property_df.dtypes
# Out:
# property_url       object
# mls                object
# mls_id             object
# status             object
# style              object
# street             object
# unit               object
# city               object
# state              object
# zip_code           object
# beds               object
# full_baths         object
# half_baths         object
# sqft               object
# year_built         object
# days_on_mls        object
# list_price         object
# list_date          object
# sold_price          int64
# last_sold_date     object
# lot_sqft           object
# price_per_sqft     object
# latitude          float64
# longitude         float64
# stories            object
# hoa_fee            object
# parking_garage     object
# primary_photo      object
# alt_photos         object
# dtype: object

# %%
property_df['last_sold_date'] = pd.to_datetime(property_df['last_sold_date'])
property_df['list_date'] = pd.to_datetime(property_df['list_date'])

# %%
num_duplicates = property_df.duplicated().sum()

print("Number of Duplicate Rows:", num_duplicates)
# Out:
# Number of Duplicate Rows: 193

# %%
missing_values = property_df.isnull().sum()

total_rows = len(property_df)

percentage_missing = (missing_values / total_rows) * 100

missing_data_summary = pd.DataFrame({
    'Column Name': missing_values.index,
    'Missing Values': missing_values.values,
    'Percentage Missing': percentage_missing.values
})

print(missing_data_summary)
# Out:
#        Column Name  Missing Values  Percentage Missing
# 0     property_url               0            0.000000
# 1              mls          148374           47.097325
# 2           mls_id          148374           47.097325
# 3           status               0            0.000000
# 4            style             475            0.150776
# 5           street               0            0.000000
# 6             unit          147431           46.797995
# 7             city               0            0.000000
# 8            state               0            0.000000
# 9         zip_code               7            0.002222
# 10            beds           90308           28.665839
# 11      full_baths           82817           26.288023
# 12      half_baths          253277           80.395953
# 13            sqft          133288           42.308681
# 14      year_built          103891           32.977396
# 15     days_on_mls          193895           61.546739
# ...

# %% [markdown]
# #### Feature engineer column specifying neighborhood using spacial join

# %%
import geopandas as gpd

# Load neighborhood boundaries data
neighborhoods = gpd.read_file('boundries-chicago.geojson')

property_df['geometry'] = gpd.points_from_xy(property_df['longitude'], property_df['latitude'])
property_df = gpd.GeoDataFrame(property_df, geometry='geometry', crs='EPSG:4326')

# Perform a spatial join
property_df = gpd.sjoin(property_df, neighborhoods, op='within')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/rashidbaset/Documents/my-projects/crime-home-price-prediction-capstone/chicago-crime-property-analysis/data-clean.ipynb Cell 55 line 1
#       <a href='vscode-notebook-cell:/Users/rashidbaset/Documents/my-projects/crime-home-price-prediction-capstone/chicago-crime-property-analysis/data-clean.ipynb#Y105sZmlsZQ%3D%3D?line=6'>7</a> property_df = gpd.GeoDataFrame(property_df, geometry='geometry', crs='EPSG:4326')
#       <a href='vscode-notebook-cell:/Users/rashidbaset/Documents/my-projects/crime-home-price-prediction-capstone/chicago-crime-property-analysis/data-clean.ipynb#Y105sZmlsZQ%3D%3D?line=8'>9</a> # Perform a spatial join
# ...

# %%
# Combine South Side neighborhoods
south_side = south_side_neighborhoods + southwest_side_neighborhoods + far_southwest_side_neighborhoods + southeast_side_neighborhoods

# Combine Central, North, and West Side neighborhoods
central_north_west = central + far_north_side + north_side + northwest_side + west_side

# %%
property_df.head(5)
# Out:
#            style  beds  sqft  year_built  days_on_mls  sold_price  \
# 0  SINGLE_FAMILY     3  1350        1890          292     10155.0
# 1  SINGLE_FAMILY     3  1300        1916           -1     57000.0
# 2  SINGLE_FAMILY     3   692        1951          202     37000.0
# 3   MULTI_FAMILY     7    -1          -1            2    175000.0
# 4  SINGLE_FAMILY     2  1437        1922          122     21000.0
#
#   last_sold_date   latitude  longitude       community    neighborhood
# 0     2014-02-11  41.737989 -87.659826  AUBURN GRESHAM  AUBURN GRESHAM
# 1     2014-02-10  41.753629 -87.651748  AUBURN GRESHAM  AUBURN GRESHAM
# 2     2014-02-10  41.750975 -87.670384  AUBURN GRESHAM  AUBURN GRESHAM
# 3     2014-02-06  41.752159 -87.647356  AUBURN GRESHAM  AUBURN GRESHAM
# 4     2014-02-06  41.756438 -87.651120  AUBURN GRESHAM  AUBURN GRESHAM

# %%
total_rows = len(property_df)

south_side_rows = property_df[property_df['community'].isin(south_side)]
south_side_percentage = (len(south_side_rows) / total_rows) * 100

central_north_west_rows = property_df[property_df['community'].isin(central_north_west)]
central_north_west_percentage = (len(central_north_west_rows) / total_rows) * 100

print(f"Percentage of rows in South Side: {south_side_percentage:.2f}%")
print(f"Percentage of rows in Central North West: {central_north_west_percentage:.2f}%")
# Out:
# Percentage of rows in South Side: 23.84%
# Percentage of rows in Central North West: 76.94%

# %%
def calculate_neighborhood_percentages(property_df, neighborhood_groups):
    total_rows = len(property_df)
    
    for group_name, neighborhood_list in neighborhood_groups.items():
        group_rows = property_df[property_df['community'].isin(neighborhood_list)]
        
        group_percentage = (len(group_rows) / total_rows) * 100
        
        print(f"Percentage of rows in {group_name}: {group_percentage:.2f}%")

neighborhood_groups = {
    "South Side Neighborhoods": south_side_neighborhoods,
    "Southwest Side Neighborhoods": southwest_side_neighborhoods,
    "Far Southwest Side Neighborhoods": far_southwest_side_neighborhoods,
    "Southeast Side Neighborhoods": southeast_side_neighborhoods,
    "Central": central,
    "Far North Side": far_north_side,
    "North Side": north_side,
    "Northwest Side": northwest_side,
    "West Side": west_side
}

calculate_neighborhood_percentages(property_df, neighborhood_groups)
# Out:
# Percentage of rows in South Side Neighborhoods: 18.43%
# Percentage of rows in Southwest Side Neighborhoods: 4.74%
# Percentage of rows in Far Southwest Side Neighborhoods: 2.35%
# Percentage of rows in Southeast Side Neighborhoods: 0.70%
# Percentage of rows in Central: 41.05%
# Percentage of rows in Far North Side: 5.93%
# Percentage of rows in North Side: 18.01%
# Percentage of rows in Northwest Side: 8.75%
# Percentage of rows in West Side: 19.64%

# %%
crime_df.columns
# Out:
# Index(['date', 'location', 'district', 'block', 'y_coordinate', 'latitude',
#        'description', 'location_description', 'updated_on', 'community_area',
#        'iucr', 'x_coordinate', 'ward', 'case_number', 'year', 'domestic',
#        'fbi_code', 'longitude', 'beat', 'primary_type', 'arrest', 'id',
#        'geometry', 'index_right', 'community', 'area', 'shape_area',
#        'perimeter', 'area_num_1', 'area_numbe', 'comarea_id', 'comarea',
#        'shape_len', 'Neighborhood'],
#       dtype='object')

# %%
crime_df.head(5)
# Out:
#                    date                                           location  \
# 0   2023-12-31 23:59:00  {'latitude': '41.900698378', 'human_address': ...
# 8   2023-12-31 23:40:00  {'latitude': '41.892753031', 'human_address': ...
# 12  2023-12-31 23:31:00  {'latitude': '41.887919288', 'human_address': ...
# 46  2023-12-31 22:34:00  {'latitude': '41.909959349', 'human_address': ...
# 77  2023-12-31 21:40:00  {'latitude': '41.903165497', 'human_address': ...
#
#     district                 block  y_coordinate   latitude  \
# 0       18.0    010XX N ORLEANS ST     1907173.0  41.900698
# 8       18.0  006XX N MICHIGAN AVE     1904307.0  41.892753
# 12      18.0      003XX N STATE ST     1902537.0  41.887919
# 46      18.0   015XX N SEDGWICK ST     1910545.0  41.909959
# 77      18.0        0000X W ELM ST     1908090.0  41.903165
#
#                       description location_description  \
# 0                      TO VEHICLE               STREET
# ...

# %%
property_df.columns
# Out:
# Index(['style', 'beds', 'sqft', 'year_built', 'days_on_mls', 'sold_price',
#        'last_sold_date', 'latitude', 'longitude', 'community', 'neighborhood'],
#       dtype='object')

# %%
columns_to_drop = ['property_url', 'mls_id', 'street', 'zip_code', 'full_baths', 'half_baths', 'list_price', 'list_date', 'lot_sqft', 'price_per_sqft', 'stories', 'hoa_fee', 'parking_garage', 'index_right', 'area', 'shape_area', 'shape_area', 'perimeter', 'area_num_1', 'area_numbe', 'comarea_id', 'comarea', 'shape_len']

property_df = property_df.drop(columns=columns_to_drop)

# %%
columns_to_drop = ['district', 'block', 'y_coordinate', 'updated_on', 'community_area', 'iucr', 'x_coordinate', 'ward', 'case_number', 'year', 'fbi_code', 'beat', 'primary_type', 'description', 'location_description', 'beat', 'district', 'ward', 'community_area', 'fbi_code']

crime_df = crime_df.drop(columns=columns_to_drop)

# %%
crime_df.columns
# Out:
# Index(['date', 'latitude', 'domestic', 'longitude', 'arrest', 'id',
#        'community', 'area', 'Neighborhood'],
#       dtype='object')

# %%
columns_to_drop = ['index_right', 'shape_area', 'perimeter', 'area_num_1', 'area_numbe', 'comarea_id', 'comarea', 'shape_len']

crime_df = crime_df.drop(columns=columns_to_drop)

# %%
crime_df.drop(columns=['geometry'], inplace=True)

# %%
# Remove duplicates from the DataFrame
crime_df = crime_df.drop_duplicates()

# %%
crime_df.shape
# Out:
# (2485061, 33)

# %% [markdown]
# ### Saving data to a database

# %%
import sqlite3

# %%
conn = sqlite3.connect('chicago-crime-property.db')
cursor = conn.cursor()

# %%
# Convert other columns to the desired data types as before
#crime_df['district'] = crime_df['district'].fillna(-1).astype(int)
#crime_df['y_coordinate'] = crime_df['y_coordinate'].astype(float)
#crime_df['x_coordinate'] = crime_df['x_coordinate'].astype(float)
#crime_df['ward'] = crime_df['ward'].fillna(-1).astype(int)
#crime_df['year'] = crime_df['year'].fillna(-1).astype(int)
crime_df['domestic'] = crime_df['domestic'].fillna(-1).astype(int)
#crime_df['beat'] = crime_df['beat'].fillna(-1).astype(int)
crime_df['arrest'] = crime_df['arrest'].fillna(-1).astype(int)

# Convert date and updated_on to strings
crime_df['date'] = crime_df['date'].astype(str)
#crime_df['updated_on'] = crime_df['updated_on'].astype(str)
crime_df['community'] = crime_df['community'].astype(str)

# Now you can insert the DataFrame into the SQL database
crime_df.to_sql('Crime', conn, if_exists='replace', index=False)

conn.commit()

# %%
property_df.to_sql('Property', conn, if_exists='replace', index=False)
conn.commit()

# %%
crime_query = "SELECT COUNT(*) FROM Crime;"
crime_count = conn.execute(crime_query).fetchone()[0]

print(f"Number of rows in 'Crime' table: {crime_count}")
# Out:
# Number of rows in 'Crime' table: 2485061

# %%
property_query = "SELECT COUNT(*) FROM Property;"
property_count = conn.execute(property_query).fetchone()[0]

print(f"Number of rows in 'Property' table: {property_count}")
# Out:
# Number of rows in 'Property' table: 313419

# %%
# Define the SQL query to create a new table 'crime_property' with the joined data
query = """
CREATE TABLE IF NOT EXISTS crime_property AS
SELECT *
FROM Property
INNER JOIN Crime ON Property.community = Crime.community
WHERE strftime('%Y', Crime.Date) = '2023';
"""

# Execute the SQL query to create the new table
conn.execute(query)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /Users/rashidbaset/Documents/my-projects/crime-home-price-prediction-capstone/chicago-crime-property-analysis/data-clean.ipynb Cell 78 line 1
#       <a href='vscode-notebook-cell:/Users/rashidbaset/Documents/my-projects/crime-home-price-prediction-capstone/chicago-crime-property-analysis/data-clean.ipynb#Y166sZmlsZQ%3D%3D?line=1'>2</a> query = """
#       <a href='vscode-notebook-cell:/Users/rashidbaset/Documents/my-projects/crime-home-price-prediction-capstone/chicago-crime-property-analysis/data-clean.ipynb#Y166sZmlsZQ%3D%3D?line=2'>3</a> CREATE TABLE IF NOT EXISTS crime_property AS
#       <a href='vscode-notebook-cell:/Users/rashidbaset/Documents/my-projects/crime-home-price-prediction-capstone/chicago-crime-property-analysis/data-clean.ipynb#Y166sZmlsZQ%3D%3D?line=3'>4</a> SELECT *
#    (...)
# ...

# %%
# Define the SQL query to create a new table 'crime_property' with the joined data
query = """
CREATE TABLE IF NOT EXISTS crime_property AS
SELECT *
FROM Property
INNER JOIN Crime ON Property.community = Crime.community
WHERE strftime('%Y', Crime.Date) BETWEEN '2019' AND '2023';
"""

# Execute the SQL query to create the new table
conn.execute(query)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /Users/rashidbaset/Documents/my-projects/crime-home-price-prediction-capstone/chicago-crime-property-analysis/data-clean.ipynb Cell 78 line 1
#       <a href='vscode-notebook-cell:/Users/rashidbaset/Documents/my-projects/crime-home-price-prediction-capstone/chicago-crime-property-analysis/data-clean.ipynb#Y165sZmlsZQ%3D%3D?line=1'>2</a> query = """
#       <a href='vscode-notebook-cell:/Users/rashidbaset/Documents/my-projects/crime-home-price-prediction-capstone/chicago-crime-property-analysis/data-clean.ipynb#Y165sZmlsZQ%3D%3D?line=2'>3</a> CREATE TABLE IF NOT EXISTS crime_property AS
#       <a href='vscode-notebook-cell:/Users/rashidbaset/Documents/my-projects/crime-home-price-prediction-capstone/chicago-crime-property-analysis/data-clean.ipynb#Y165sZmlsZQ%3D%3D?line=3'>4</a> SELECT *
#    (...)
# ...

# %%
conn = sqlite3.connect('your_database.db')

# %%
property_df.to_sql('Property', conn, if_exists='replace', index=False)

crime_df.to_sql('Crime', conn, if_exists='replace', index=False)

conn.commit()

# %%
import pandas as pd
import sqlite3  # Replace with your database library if needed

# Connect to the database
conn = sqlite3.connect('your_database.db')  # Replace with your database connection details

# Execute the SQL query and store the result in a DataFrame
merged_df = pd.read_sql_query("SELECT * FROM Property INNER JOIN Crime ON Property.community = Crime.community;", conn)

# Close the database connection
conn.close()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/sql.py:2262, in SQLiteDatabase.execute(self, sql, params)
#    2261 try:
# -> 2262     cur.execute(sql, *args)
#    2263     return cur
#
# OperationalError: no such table: Property
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# /Users/rashidbaset/Documents/my-projects/crime-home-price-prediction-capstone/chicago-crime-property-analysis/data-clean.ipynb Cell 68 line 8
#       <a href='vscode-notebook-cell:/Users/rashidbaset/Documents/my-projects/crime-home-price-prediction-capstone/chicago-crime-property-analysis/data-clean.ipynb#Y143sZmlsZQ%3D%3D?line=4'>5</a> conn = sqlite3.connect('your_database.db')  # Replace with your database connection details
# ...

# %%
db_path = 'chicago-crime-property.db'

# %%
conn = sqlite3.connect('chicago-cirme-property.db')

cursor = conn.cursor()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/rashidbaset/Documents/my-projects/crime-home-price-prediction-capstone/chicago-crime-property-analysis/data-clean.ipynb Cell 80 line 1
# ----> <a href='vscode-notebook-cell:/Users/rashidbaset/Documents/my-projects/crime-home-price-prediction-capstone/chicago-crime-property-analysis/data-clean.ipynb#Y115sZmlsZQ%3D%3D?line=0'>1</a> conn = sqlite3.connect('chicago-cirme-property.db')
#       <a href='vscode-notebook-cell:/Users/rashidbaset/Documents/my-projects/crime-home-price-prediction-capstone/chicago-crime-property-analysis/data-clean.ipynb#Y115sZmlsZQ%3D%3D?line=2'>3</a> cursor = conn.cursor()
#
# NameError: name 'sqlite3' is not defined

# %%
merged_df = pd.read_sql_query("SELECT * FROM Property INNER JOIN Crime ON Property.community = Crime.community;", conn)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/sql.py:2262, in SQLiteDatabase.execute(self, sql, params)
#    2261 try:
# -> 2262     cur.execute(sql, *args)
#    2263     return cur
#
# OperationalError: no such column: Property.community
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# /Users/rashidbaset/Documents/my-projects/crime-home-price-prediction-capstone/chicago-crime-property-analysis/data-clean.ipynb Cell 71 line 1
# ...
